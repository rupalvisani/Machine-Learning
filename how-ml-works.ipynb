# %%
import numpy as np

# %%
X,Y = np.loadtxt("C:\Pizza.txt",skiprows = 1, unpack = True)

# %%
X
# Out:
# array([13.,  2., 14., 23., 13., 13.,  1., 18.,  7.])

# %%
Y
# Out:
# array([33., 16., 32., 51., 27., 25., 16., 34., 22.])

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
plt.xlabel("Reservations",fontsize = 20)
plt.ylabel("Pizzas",fontsize = 20)
plt.axis([0,50,0,50])
plt.plot(X,Y,"bo")
plt.show()

# %%
def predict(X,W,b):
    return X*W+b

# %%
predict(14,12,1.3)
# Out:
# 169.3

# %%
reservations = np.array([14,5,5])
predict(reservations,12,12)
# Out:
# array([180,  72,  72])

# %%
def loss(X,Y,W,b):
    predictions = predict(X,W,b)
    return np.average((predictions - Y)**2)

# %%
loss(X,Y,1.2,12)
# Out:
# 21.066666666666677

# %%
def train(X,Y,iterations,lr):
    W=b=0
    
    
    current_loss = loss(X,Y,W,b)
    
    for i in range(iterations):
        current_loss = loss(X,Y,W,b)
        print("found loss")
        
        if loss(X,Y,W-lr,b)< current_loss:
           W-=lr  
        elif loss(X,Y,W+lr,b)< current_loss:
           W+=lr
        elif loss(X,Y,W,b-lr)< current_loss:
           b-=lr
        elif loss(X,Y,W,b+lr)< current_loss:
           b+=lr
        else:
            return W,b
        
    raise Exception("Not found")

# %%
W,b = train(X,Y,10000,0.01)
# Out:
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss
# found loss

# %%
W
# Out:
# 1.4400000000000008

# %%
b
# Out:
# 11.799999999999793

# %%
plt.xlabel("Reservation",fontsize= 20)
plt.ylabel("Pizzas",fontsize = 20)
plt.axis([0,50,0,50])
plt.plot(X,Y,"bo")
plt.plot([0,50],[b,predict(50,W,b)],color = "g")
plt.show()
